# %% [markdown]
# <a href="https://colab.research.google.com/github/salma-benzakour/Text-Classification-Judgment-Prediction/blob/main/Best_Model_Selection.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pickle
import pandas as pd

# %%
path_pickles = "drive/MyDrive/"

list_pickles = [
    "df_models_gbc.pickle",
    "df_models_knnc.pickle",
    "df_models_lrc.pickle",
    "df_models_mnbc.pickle",
    "df_models_rfc (1).pickle",
    "df_models_svc.pickle"
]

df_summary = pd.DataFrame()

for pickle_ in list_pickles:

    path = path_pickles + pickle_

    with open(path, 'rb') as data:
        df = pickle.load(data)

    df_summary = df_summary.append(df)

df_summary = df_summary.reset_index().drop('index', axis=1)
# Out:
# <ipython-input-6-019a58cbd87a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_summary = df_summary.append(df)
# <ipython-input-6-019a58cbd87a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_summary = df_summary.append(df)
# <ipython-input-6-019a58cbd87a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_summary = df_summary.append(df)
# <ipython-input-6-019a58cbd87a>:21: FutureWarning: The frame.append method is deprecated and will be removed from pandas in a future version. Use pandas.concat instead.
#   df_summary = df_summary.append(df)
# ...

# %%
df_summary
# Out:
#                      Model  Training Set Accuracy  Test Set Accuracy
# 0        Gradient Boosting               1.000000           0.940120
# 1                      KNN               0.959810           0.928144
# 2      Logistic Regression               0.981491           0.940120
# 3  Multinomial Naïve Bayes               0.953993           0.934132
# 4            Random Forest               1.000000           0.928144
# 5                      SVM               0.959281           0.940120

# %%
df_summary.sort_values('Test Set Accuracy', ascending=False)
# Out:
#                      Model  Training Set Accuracy  Test Set Accuracy
# 0        Gradient Boosting               1.000000           0.940120
# 2      Logistic Regression               0.981491           0.940120
# 5                      SVM               0.959281           0.940120
# 3  Multinomial Naïve Bayes               0.953993           0.934132
# 1                      KNN               0.959810           0.928144
# 4            Random Forest               1.000000           0.928144
